# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('googleplaystore.csv')
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %% [markdown]
# 1. Display Top 5 Rows of The Dataset

# %%
df.head(5)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %% [markdown]
# 2. Check the Last 3 Rows of The Dataset

# %%
df.tail(3)
# Out:
#                                                  App             Category  \
# 10838                         Parkinson Exercices FR              MEDICAL
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating             Genres      Last Updated         Current Ver  \
# 10838       Everyone            Medical  January 20, 2017                 1.0
# 10839     Mature 17+  Books & Reference  January 19, 2015  Varies with device
# 10840       Everyone          Lifestyle     July 25, 2018  Varies with device
#
#               Android Ver
# 10838          2.2 and up
# 10839  Varies with device
# ...

# %% [markdown]
# 3. Find Shape of Our Dataset (Number of Rows & Number of Columns)

# %%
df.shape
# Out:
# (10841, 13)

# %% [markdown]
# 4. Get Information About Our Dataset Like Total Number Rows, Total Number of Columns, Datatypes of Each Column And Memory Requirement

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %% [markdown]
# 5. Get Overall Statistics About The Dataframe

# %%
df.describe()
# Out:
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %% [markdown]
# 6. Total Number of App Titles Contain Astrology

# %%
df
len(df[df['App'].str.contains('Astrology')])
# Out:
# 3

# %% [markdown]
# 7. Find Average App Rating

# %%
print('Average App Rating is',df['Rating'].mean())
# Out:
# Average App Rating is 4.193338315362448

# %% [markdown]
# 8.  Find Total Number of Unique Category

# %%
df.Category.unique()
# Out:
# array(['ART_AND_DESIGN', 'AUTO_AND_VEHICLES', 'BEAUTY',
#        'BOOKS_AND_REFERENCE', 'BUSINESS', 'COMICS', 'COMMUNICATION',
#        'DATING', 'EDUCATION', 'ENTERTAINMENT', 'EVENTS', 'FINANCE',
#        'FOOD_AND_DRINK', 'HEALTH_AND_FITNESS', 'HOUSE_AND_HOME',
#        'LIBRARIES_AND_DEMO', 'LIFESTYLE', 'GAME', 'FAMILY', 'MEDICAL',
#        'SOCIAL', 'SHOPPING', 'PHOTOGRAPHY', 'SPORTS', 'TRAVEL_AND_LOCAL',
#        'TOOLS', 'PERSONALIZATION', 'PRODUCTIVITY', 'PARENTING', 'WEATHER',
#        'VIDEO_PLAYERS', 'NEWS_AND_MAGAZINES', 'MAPS_AND_NAVIGATION',
#        '1.9'], dtype=object)

# %% [markdown]
# 9. Which Category Getting The Highest Average Rating?

# %%
df
df.groupby(by='Category')['Rating'].mean().sort_values(ascending=False)
# Out:
# Category
# 1.9                    19.000000
# EVENTS                  4.435556
# EDUCATION               4.389032
# ART_AND_DESIGN          4.358065
# BOOKS_AND_REFERENCE     4.346067
# PERSONALIZATION         4.335987
# PARENTING               4.300000
# GAME                    4.286326
# BEAUTY                  4.278571
# HEALTH_AND_FITNESS      4.277104
# SHOPPING                4.259664
# SOCIAL                  4.255598
# WEATHER                 4.244000
# SPORTS                  4.223511
# PRODUCTIVITY            4.211396
# HOUSE_AND_HOME          4.197368
# FAMILY                  4.192272
# PHOTOGRAPHY             4.192114
# AUTO_AND_VEHICLES       4.190411
# MEDICAL                 4.189143
# LIBRARIES_AND_DEMO      4.178462
# FOOD_AND_DRINK          4.166972
# COMMUNICATION           4.158537
# COMICS                  4.155172
# NEWS_AND_MAGAZINES      4.132189
# FINANCE                 4.131889
# ENTERTAINMENT           4.126174
# BUSINESS                4.121452
# ...

# %% [markdown]
# 10. Find Total Number of App having 5 Star Rating

# %%
df
#len(df[df.Rating==5]['App'])
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %% [markdown]
# 11. Find Average Value of Reviews

# %%
round(df.Reviews.replace("3.0M",3000000).astype("int").mean(),2)
# Out:
# 444388.65

# %% [markdown]
# 12. Find Total Number of Free and Paid Apps

# %%
#df.groupby(by="Type").count()["App"]
df.Type.value_counts()
# Out:
# Free    10039
# Paid      800
# 0           1
# Name: Type, dtype: int64

# %% [markdown]
# 13.  Which App Has Maximum Reviews?

# %%
df[df.Reviews.replace("3.0M",3000000).astype("int") == df.Reviews.replace("3.0M",3000000).astype("int").max()]["App"]
# Out:
# 2544    Facebook
# Name: App, dtype: object

# %%
df.Reviews.replace("3.0M",3000000,inplace=True)

# %% [markdown]
# 14. Display Top 5 Apps Having Highest Reviews

# %%
df[["App","Reviews"]].sort_values(by="Reviews").tail()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\SWAPNI~1\AppData\Local\Temp/ipykernel_13912/2692451556.py in <module>
# ----> 1 df[["App","Reviews"]].sort_values(by="Reviews").tail()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    6268                 ascending = ascending[0]
#    6269
# -> 6270             indexer = nargsort(
#    6271                 k, kind=kind, ascending=ascending, na_position=na_position, key=key
#    6272             )
#
# ...

# %% [markdown]
# 15. Find Average Rating of Free and Paid Apps

# %%
df.groupby(by="Type").mean()["Rating"]

# %% [markdown]
# 16. Display Top  5 Apps Having Maximum Installs

# %%
df.Installs = df.Installs.str.replace('Free','0')

# %%
df.Installs = df.Installs.astype('int')

# %%
df[["App","Installs"]].sort_values(by="Installs").tail()

# %%
df.Installs = df.Installs.str.replace("+","").str.replace(",","").str.replace("Free","0").astype("int")

# %%
df.Size=df.Size.str.replace('M','000000')
df.Type.value_counts()

# %%
from datetime import datetime as dtm

# %%
time.strptime("2022 January 2", "%Y %M %d")

# %%
df["Last Updated"].replace("1.0.19","February 11, 2018",inplace=True)

# %%
df['Last Updated']=pd.to_datetime(df['Last Updated'],format=  "%M %d, %Y" ,infer_datetime_format=True)

# %%
df

# %%
df

# %%
df2=df.copy()
df2[['Month','Day','Year']]=df2['Last Updated'].str.split(expand=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\SWAPNI~1\AppData\Local\Temp/ipykernel_13912/3951373065.py in <module>
#       1 df2=df.copy()
# ----> 2 df2[['Month','Day','Year']]=df2['Last Updated'].str.split(expand=True)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     179             # we're accessing the attribute of the class, i.e., Dataset.geo
#     180             return self._accessor
# --> 181         accessor_obj = self._accessor(obj)
#     182         # Replace the property with the accessor object. Inspired by:
# ...

# %%
df2.Day=df2.Day.str.replace(',','')

# %%
df2['Lupdated']=df2['Month']+" "+df2['Day']+" "+df2['Year']

# %%
df2.Year.value_counts()

# %%
pd.to_datetime("August 1, 2018",format="%M %d, %Y" ,infer_datetime_format=True)

# %%
df['Year']=df['Last Updated'].dt.year

# %%
df2
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df2['Size']=df2['Size'].str[:-1]

# %%
df2.replace('Varies with devic',0,inplace=True)
df2['Size']=df2.Size.str.replace(',','')

# %%
df2.Size.value_counts()
# Out:
# Varies with devic    1695
# 11                    199
# 12                    196
# 14                    195
# 13                    191
#                      ...
# 429                     1
# 200                     1
# 460                     1
# 728                     1
# 619                     1
# Name: Size, Length: 423, dtype: int64

# %%
df2.Size.astype('float')
# Out:
# 0        19.0
# 1        14.0
# 2         8.7
# 3        25.0
# 4         2.8
#          ...
# 10836    53.0
# 10837     3.6
# 10838     9.5
# 10839     NaN
# 10840    19.0
# Name: Size, Length: 10841, dtype: float64

# %%
df2
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df2[df2['Type']=='Free']['Category'].value_counts()
# Out:
# FAMILY                 1780
# GAME                   1061
# TOOLS                   765
# BUSINESS                446
# PRODUCTIVITY            396
# LIFESTYLE               363
# COMMUNICATION           360
# SPORTS                  360
# MEDICAL                 354
# FINANCE                 349
# HEALTH_AND_FITNESS      325
# PHOTOGRAPHY             313
# PERSONALIZATION         309
# SOCIAL                  292
# NEWS_AND_MAGAZINES      281
# SHOPPING                258
# TRAVEL_AND_LOCAL        246
# DATING                  227
# BOOKS_AND_REFERENCE     203
# VIDEO_PLAYERS           171
# EDUCATION               152
# ENTERTAINMENT           147
# MAPS_AND_NAVIGATION     132
# FOOD_AND_DRINK          125
# HOUSE_AND_HOME           88
# LIBRARIES_AND_DEMO       84
# AUTO_AND_VEHICLES        82
# WEATHER                  74
# EVENTS                   63
# ART_AND_DESIGN           62
# COMICS                   60
# PARENTING                58
# BEAUTY                   53
# ...

# %%
print('There are' ,len(df2[df2.Category.str.contains('GAME')]),'of Games.')
# Out:
# There are 1144 of Games.

# %%
df2.Installs=df2.Installs.str.replace('+','').str.replace(',','').replace('Free',0)
# Out:
# C:\Users\SWAPNI~1\AppData\Local\Temp/ipykernel_13912/201058376.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df2.Installs=df2.Installs.str.replace('+','').str.replace(',','').replace('Free',0)

# %%
df2.Installs.astype('int')
# Out:
# 0           10000
# 1          500000
# 2         5000000
# 3        50000000
# 4          100000
#            ...
# 10836        5000
# 10837         100
# 10838        1000
# 10839        1000
# 10840    10000000
# Name: Installs, Length: 10841, dtype: int32

# %%
df2[df2.Category=='GAME']['Installs'].astype('int').sum()+df2[df2.Category=='DATING']['Installs'].astype('int').sum()
# Out:
# 35350335222

# %%
df2[(df2.Category=='GAME') | (df2.Category=='DATING')]['Installs'].astype('int').sum()
# Out:
# 35350335222

# %%
df3=df2.isnull().sum(axis=1)
df3.index
len(df3)
# Out:
# 10841

# %%
a=0
for index,values in enumerate(df3):
    if values>=1:
        a=a+1
print(a)
# Out:
# 3118

# %%
l1=[]
for index,values in enumerate(df3):
    if values>=1:
        l1.append(index)
df.iloc[l1]
# Out:
#                                              App             Category  Rating  \
# 15               Learn To Draw Kawaii Characters       ART_AND_DESIGN     3.2
# 23                        Mcqueen Coloring pages       ART_AND_DESIGN     NaN
# 37                            Floor Plan Creator       ART_AND_DESIGN     4.1
# 42                    Textgram - write on photos       ART_AND_DESIGN     4.4
# 52                 Used Cars and Trucks for Sale    AUTO_AND_VEHICLES     4.6
# ...                                          ...                  ...     ...
# 10826  Frim: get new friends on local chat rooms               SOCIAL     4.0
# 10831                   payermonstationnement.fr  MAPS_AND_NAVIGATION     NaN
# 10835                                   FR Forms             BUSINESS     NaN
# 10838                     Parkinson Exercices FR              MEDICAL     NaN
# 10839              The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE     4.5
#
# ...

# %%
l2=[ x for x,y in enumerate(df3) if y>=1 ]
df.iloc[l2]
# Out:
#                                              App             Category  Rating  \
# 15               Learn To Draw Kawaii Characters       ART_AND_DESIGN     3.2
# 23                        Mcqueen Coloring pages       ART_AND_DESIGN     NaN
# 37                            Floor Plan Creator       ART_AND_DESIGN     4.1
# 42                    Textgram - write on photos       ART_AND_DESIGN     4.4
# 52                 Used Cars and Trucks for Sale    AUTO_AND_VEHICLES     4.6
# ...                                          ...                  ...     ...
# 10826  Frim: get new friends on local chat rooms               SOCIAL     4.0
# 10831                   payermonstationnement.fr  MAPS_AND_NAVIGATION     NaN
# 10835                                   FR Forms             BUSINESS     NaN
# 10838                     Parkinson Exercices FR              MEDICAL     NaN
# 10839              The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE     4.5
#
# ...
