# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import plotly.express as px
import seaborn as sns

# %%
df=pd.read_csv('udemy_courses.csv')

# %% [markdown]
# 1. Display Top 10 Rows of The Dataset

# %%
df.head(10)
# Out:
#    course_id                                       course_title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course & Certification - Grow You...
# 2    1006314  Financial Modeling for Business Analysts and C...
# 3    1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4    1011058       How To Maximize Your Profits Trading Options
# 5     192870  Trading Penny Stocks: A Guide for All Levels I...
# 6     739964  Investing And Trading For Beginners: Mastering...
# 7     403100  Trading Stock Chart Patterns For Immediate, Ex...
# 8     476268  Options Trading 3 : Advanced Stock Profit and ...
# 9    1167710  The Only Investment Strategy You Need For Your...
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
# 1      https://www.udemy.com/goods-and-services-tax/     True     75
# ...

# %% [markdown]
# 2. Check Last 5 Rows of The Dataset

# %%
df.tail(5)
# Out:
#       course_id                                       course_title  \
# 3673     775618  Learn jQuery from Scratch - Master of JavaScri...
# 3674    1088178  How To Design A WordPress Website With No Codi...
# 3675     635248                      Learn and Build using Polymer
# 3676     905096  CSS Animations: Create Amazing Effects on Your...
# 3677     297602  Using MODX CMS to Build Websites: A Beginner's...
#
#                                                     url  is_paid  price  \
# 3673  https://www.udemy.com/easy-jquery-for-beginner...     True    100
# 3674  https://www.udemy.com/how-to-make-a-wordpress-...     True     25
# 3675  https://www.udemy.com/learn-and-build-using-po...     True     40
# 3676  https://www.udemy.com/css-animations-create-am...     True     50
# 3677  https://www.udemy.com/using-modx-cms-to-build-...     True     45
#
#       num_subscribers  num_reviews  num_lectures           level  \
# ...

# %% [markdown]
# 3. Find Shape of Our Dataset (Number of Rows And Number of Columns)

# %%
df.shape
# Out:
# (3678, 12)

# %% [markdown]
# 4. Getting Information About Our Dataset Like Total Number Rows, Total Number of Columns, Datatypes of Each Column And Memory Requirement

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3678 entries, 0 to 3677
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   course_id            3678 non-null   int64
#  1   course_title         3678 non-null   object
#  2   url                  3678 non-null   object
#  3   is_paid              3678 non-null   bool
#  4   price                3678 non-null   int64
#  5   num_subscribers      3678 non-null   int64
#  6   num_reviews          3678 non-null   int64
#  7   num_lectures         3678 non-null   int64
#  8   level                3678 non-null   object
#  9   content_duration     3678 non-null   float64
#  10  published_timestamp  3678 non-null   object
#  11  subject              3678 non-null   object
# dtypes: bool(1), float64(1), int64(5), object(5)
# memory usage: 319.8+ KB

# %% [markdown]
# 5. Check Null Values In The Dataset

# %%
df.isnull().sum()
# Out:
# course_id              0
# course_title           0
# url                    0
# is_paid                0
# price                  0
# num_subscribers        0
# num_reviews            0
# num_lectures           0
# level                  0
# content_duration       0
# published_timestamp    0
# subject                0
# dtype: int64

# %% [markdown]
# 6. Check For Duplicate Data and Drop Them

# %%
df.drop_duplicates(inplace=True)
df
# Out:
#       course_id                                       course_title  \
# 0       1070968                 Ultimate Investment Banking Course
# 1       1113822  Complete GST Course & Certification - Grow You...
# 2       1006314  Financial Modeling for Business Analysts and C...
# 3       1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4       1011058       How To Maximize Your Profits Trading Options
# ...         ...                                                ...
# 3673     775618  Learn jQuery from Scratch - Master of JavaScri...
# 3674    1088178  How To Design A WordPress Website With No Codi...
# 3675     635248                      Learn and Build using Polymer
# 3676     905096  CSS Animations: Create Amazing Effects on Your...
# 3677     297602  Using MODX CMS to Build Websites: A Beginner's...
#
#                                                     url  is_paid  price  \
# 0     https://www.udemy.com/ultimate-investment-bank...     True    200
# ...

# %% [markdown]
# 7. Find Out Number of Courses Per Subjects

# %%
df.subject.value_counts()
df.subject.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
sns.countplot(x='subject',data=df)
plt.xticks(rotation=75)
plt.show()

# %%
px.bar(x='subject',data_frame=df)
# Out:
# <div>                            <div id="b29bf726-bd98-4ddc-aaee-407d128643ae" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b29bf726-bd98-4ddc-aaee-407d128643ae")) {                    Plotly.newPlot(                        "b29bf726-bd98-4ddc-aaee-407d128643ae",                        [{"alignmentgroup":"True","hovertemplate":"subject=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Business Finance","Business Finance","Business Finance","Business Finance","Business Finance","Business Finance","Business Finance","Business Finance","Business Finance","Business Finance","Business Finance","Business Fin
# ...

# %%
df.groupby(by='subject')['course_title'].count()
# Out:
# subject
# Business Finance       1191
# Graphic Design          602
# Musical Instruments     680
# Web Development        1199
# Name: course_title, dtype: int64

# %% [markdown]
# 8. For Which Levels, Udemy Courses Providing The Courses

# %%
df.level.value_counts()
# Out:
# All Levels            1925
# Beginner Level        1268
# Intermediate Level     421
# Expert Level            58
# Name: level, dtype: int64

# %%
sns.countplot(x='level',data=df)
# Out:
# <AxesSubplot:xlabel='level', ylabel='count'>

# %% [markdown]
# 9. Display The Count of Paid and Free Courses

# %%
df.is_paid.value_counts()
print('the count of paid courses is ',df.is_paid.value_counts()[0])
print('the count of free courses is ',df.is_paid.value_counts()[1])
# Out:
# the count of paid courses is  310
# the count of free courses is  3362

# %%
sns.countplot(x=df['is_paid'].map(lambda x : "Free" if x == False else "Paid"))
# Out:
# <AxesSubplot:xlabel='is_paid', ylabel='count'>

# %%
df['is_paid'].apply(lambda x : "Free" if x == False else "Paid").value_counts()
# Out:
# Paid    3362
# Free     310
# Name: is_paid, dtype: int64

# %% [markdown]
# 10. Which Course Has More Lectures (Free or Paid)?

# %%
df
df.groupby('is_paid').sum()['num_lectures'].sort_values(ascending=False)
# Out:
# is_paid
# True     140756
# False      6639
# Name: num_lectures, dtype: int64

# %% [markdown]
# 11. Which Courses Have A Higher Number of Subscribers Free or Paid?

# %%
df
df.groupby('is_paid').sum()['num_subscribers'].sort_values(ascending=False)
# Out:
# is_paid
# True     8140310
# False    3575525
# Name: num_subscribers, dtype: int64

# %% [markdown]
# 12. Which Level Has The Highest Number of Subscribers?

# %%
df
df.groupby(by='level').sum()['num_subscribers'].sort_values(ascending=False).head(1)
# Out:
# level
# All Levels    6871791
# Name: num_subscribers, dtype: int64

# %% [markdown]
# 13. Find Most Popular Course Title

# %%
df.sort_values(by='num_subscribers',ascending=False)[['course_title','num_subscribers']].head(1)
# Out:
#                               course_title  num_subscribers
# 2827  Learn HTML5 Programming From Scratch           268923

# %%
df
df.groupby(by='course_title').sum()['num_subscribers'].sort_values(ascending=False).head(1)
# Out:
# course_title
# Learn HTML5 Programming From Scratch    268923
# Name: num_subscribers, dtype: int64

# %% [markdown]
# 14. Display 10 Most Popular Courses As Per Number of Subscribers

# %%
df.sort_values(by='num_subscribers',ascending=False)['course_title'].head(10)
# Out:
# 2827                 Learn HTML5 Programming From Scratch
# 3032                       Coding for Entrepreneurs Basic
# 3230                           The Web Developer Bootcamp
# 2783    Build Your First Website in 1 Week with HTML5 ...
# 3232                The Complete Web Developer Course 2.0
# 1896                Free Beginner Electric Guitar Lessons
# 2589    Web Design for Web Developers: Build Beautiful...
# 2619               Learn Javascript & JQuery From Scratch
# 3289    Practical PHP: Master the Basics and Code Dyna...
# 3247            JavaScript: Understanding the Weird Parts
# Name: course_title, dtype: object

# %% [markdown]
# 15. Find The Course Which Is Having The Highest Number of Reviews.

# %%
df
df.groupby(by='course_title').sum()['num_reviews'].sort_values(ascending=False).head(1)
# Out:
# course_title
# The Web Developer Bootcamp    27445
# Name: num_reviews, dtype: int64

# %% [markdown]
# 16. Does Price Affect the Number of Reviews?

# %%
df.price.value_counts().sort_values(ascending=False)
sns.scatterplot(x='price',y='num_reviews',data=df,color='orange')
# Out:
# <AxesSubplot:xlabel='price', ylabel='num_reviews'>

# %% [markdown]
# 17. Find Total Number of Courses Related To Python

# %%
len(df[df.course_title.str.contains('Python')])
print('Total No. of course related to python are ',len(df[df.course_title.str.contains('Python')]))
# Out:
# Total No. of course related to python are  29

# %% [markdown]
# 18. Display 10 Most Popular Python Courses As Per Number of Subscribers

# %%
df
df[df.course_title.str.contains('Python')].sort_values(by='num_subscribers',ascending=False)[['course_title','num_subscribers']]
# Out:
#                                            course_title  num_subscribers
# 2497                        Web Programming with Python            35267
# 2570  Coding for Entrepreneurs: Learn Python, Django...            23412
# 2528        Learn Python and Django: Payment Processing            17714
# 3200  Python and Django Full Stack Web Developer Boo...            11832
# 3507  Fun and creative web engineering with Python a...            10917
# 2553  The Complete Ethical Hacking Course 2.0: Pytho...             7827
# 3138  Complete Python Web Course: Build 8 Python Web...             7489
# 3197  Try Django 1.9 | Build a Blog and Learn Python...             7407
# 2681  Python for Beginners: Python Programming Langu...             6153
# 3203                    REST APIs with Flask and Python             5151
# 3392  Python Programming: Create an Digital Marketpl...             4198
# 41    Python for Finance: Investment Fundamentals & ...             3811
# ...

# %% [markdown]
# 19. In Which Year The Highest Number of Courses Were Posted?

# %%
df['published_timestamp']
df.published_timestamp=pd.to_datetime(df['published_timestamp'])
df['year']=df.published_timestamp.dt.year
df.year.value_counts()
# Out:
# 2016    1204
# 2015    1014
# 2017     713
# 2014     490
# 2013     201
# 2012      45
# 2011       5
# Name: year, dtype: int64

# %% [markdown]
# 20. Display Category-Wise Count of Posted Subjects [Year Wise]

# %%
df.subject.value_counts()
# Out:
# Web Development        1199
# Business Finance       1191
# Musical Instruments     680
# Graphic Design          602
# Name: subject, dtype: int64
