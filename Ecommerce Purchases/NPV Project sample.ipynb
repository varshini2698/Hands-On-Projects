# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv("Ecommerce Purchases.csv")

# %%
df
# Out:
#                                                 Address    Lot AM or PM  \
# 0     16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                      Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4     23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# ...                                                 ...    ...      ...
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# ...

# %%
df.columns
# Out:
# Index(['Address', 'Lot', 'AM or PM', 'Browser Info', 'Company', 'Credit Card',
#        'CC Exp Date', 'CC Security Code', 'CC Provider', 'Email', 'Job',
#        'IP Address', 'Language', 'Purchase Price'],
#       dtype='object')

# %% [markdown]
# To perform data analysis, I have mentioned 15 questions that we are going to solve one by one. Questions are as follows.
# 1. Display Top 10 Rows of The Dataset

# %%
df.head(10)
# Out:
#                                              Address    Lot AM or PM  \
# 0  16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1  9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                   Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3              7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4  23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# 5  7502 Powell Mission Apt. 768\nTravisland, VA 3...  21 XT       PM
# 6     93971 Conway Causeway\nAndersonburgh, AZ 75107  96 Xt       AM
# 7  260 Rachel Plains Suite 366\nCastroberg, WV 24...  96 pG       PM
# 8            2129 Dylan Burg\nNew Michelle, ME 28650  45 JN       PM
# 9    3795 Dawson Extensions\nLake Tinafort, ID 88739  15 Ug       AM
#
#                                         Browser Info  \
# 0  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# 1  Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
# ...

# %% [markdown]
# 2. Check Last 10 Rows of The Dataset

# %%
df.tail(10)
# Out:
#                                                 Address    Lot AM or PM  \
# 9990  75731 Molly Springs\nWest Danielle, VT 96934-5102  93 ty       PM
# 9991              PSC 8165, Box 8498\nAPO AP 60327-0346  50 dA       AM
# 9992  885 Allen Mountains Apt. 230\nWallhaven, LA 16995  40 vH       PM
# 9993  7555 Larson Locks Suite 229\nEllisburgh, MA 34...  72 jg       PM
# 9994       6276 Rojas Hollow\nLake Louis, WY 56410-7837  93 Ex       PM
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# 9990  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_7_4;...
# 9991  Mozilla/5.0 (compatible; MSIE 8.0; Windows NT ...
# ...

# %% [markdown]
# 3. Check Datatype of Each Column

# %%
df.dtypes
# Out:
# Address              object
# Lot                  object
# AM or PM             object
# Browser Info         object
# Company              object
# Credit Card           int64
# CC Exp Date          object
# CC Security Code      int64
# CC Provider          object
# Email                object
# Job                  object
# IP Address           object
# Language             object
# Purchase Price      float64
# dtype: object

# %% [markdown]
# 4. Check null values in the dataset

# %%
df.isnull().any()
# Out:
# Address             False
# Lot                 False
# AM or PM            False
# Browser Info        False
# Company             False
# Credit Card         False
# CC Exp Date         False
# CC Security Code    False
# CC Provider         False
# Email               False
# Job                 False
# IP Address          False
# Language            False
# Purchase Price      False
# dtype: bool

# %% [markdown]
# 5. How many rows and columns are there in our Dataset?

# %%
len(df.index) , len(df.columns)
# Out:
# (10000, 14)

# %% [markdown]
# 6. Highest and Lowest Purchase Prices.

# %%
print("Max Value: ",df["Purchase Price"].max())
print("Min Value: ",df["Purchase Price"].min())
# Out:
# Max Value:  99.99
# Min Value:  0.0

# %%
#df["Purchase Price"].sort_values(ascending=False)
df.sort_values(by="Purchase Price",ascending=False)[["Purchase Price","Company"]].head(1)
# Out:
#       Purchase Price      Company
# 2092           99.99  Pitts Group

# %% [markdown]
# 7. Average Purchase Price

# %%
round(df["Purchase Price"].mean(),2)
# Out:
# 50.35

# %% [markdown]
# 8. How many people have French 'fr' as their Language?

# %%
#df[df["Language"] == "fr"]["Language"].count()
len(df[df["Language"] == "fr"])
# Out:
# 1097

# %% [markdown]
# 9. Job Title Contains Engineer

# %%
df[df["Job"].str.contains("engineer")]["Job"].unique()
# Out:
# array(['Drilling engineer', 'Mechanical engineer',
#        'Technical sales engineer', 'Energy engineer', 'Water engineer',
#        'Software engineer', 'Structural engineer', 'Mining engineer',
#        'Manufacturing systems engineer',
#        'Control and instrumentation engineer',
#        'Consulting civil engineer', 'Site engineer', 'Petroleum engineer',
#        'Communications engineer', 'Civil engineer, consulting',
#        'Automotive engineer', 'Contracting civil engineer',
#        'Maintenance engineer', 'Broadcast engineer',
#        'Agricultural engineer', 'Electrical engineer',
#        'Manufacturing engineer', 'Chemical engineer',
#        'Biomedical engineer', 'Civil engineer, contracting',
#        'Materials engineer', 'Network engineer', 'Geologist, engineering',
#        'Building services engineer', 'Production engineer',
#        'Aeronautical engineer', 'Electronics engineer'], dtype=object)

# %% [markdown]
# 10. Find The Email of the person with the following IP Address: 132.207.160.22

# %%
a = [i for v,i in zip(df.index,df[df["IP Address"] == "132.207.160.22"]["Email"])]

print("The email address for the person with IP Add 132.207.160.22 is", a[0])


#df[df["IP Address"].str.contains("132.207.160.22")]["Email"]
# Out:
# The email address for the person with IP Add 132.207.160.22 is amymiller@morales-harrison.com
# ['amymiller@morales-harrison.com']

# %% [markdown]
# 11. How many People have Mastercard as their Credit Card Provider and made a purchase above 50?

# %%
len(df[(df["CC Provider"] == "Mastercard") & (df["Purchase Price"] > 50)])
# Out:
# 405

# %% [markdown]
# 12. Find the email of the person with the following Credit Card Number: 4664825258997302

# %%
print('Email of the person with the following Credit Card Number: 4664825258997302 is',df[df['Credit Card']==4664825258997302]['Email'].values[0])
# Out:
# Email of the person with the following Credit Card Number: 4664825258997302 is bberry@wright.net

# %%
Credit Card

# %% [markdown]
# 13. How many people purchase during the AM and how many people purchase during PM?

# %%
print(len(df[df['AM or PM']=='AM']),"people purchased during the AM.")
print(len(df[df['AM or PM']=='PM']),"people purchased during the PM.")
# Out:
# 4932 people purchased during the AM.
# 5068 people purchased during the PM.

# %% [markdown]
# 14. How many people have a credit card that expires in 2020?

# %%
len(df[df['CC Exp Date'].str[-2:]=='20'])
# Out:
# 988

# %% [markdown]
# 15. What are the top 5 most popular email providers (e.g. gmail.com, yahoo.com, etc...)

# %%
df1["Eemail"] = [i for v,i in df["Email"].str.split("@").values]

# %%
df1["Eemail2"] = [i for v,i in df["Email"].str.split("@")]
df1

list1=[]
for i in df.Email:
    list1.append(i.split('@')[1])
# Out:
#                                                 Address    Lot AM or PM  \
# 0     16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                      Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4     23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# ...                                                 ...    ...      ...
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# ...

# %%
df1["Eemail"].value_counts().head()
# Out:
# hotmail.com     1638
# yahoo.com       1616
# gmail.com       1605
# smith.com         42
# williams.com      37
# Name: Eemail, dtype: int64

# %%
li = []
for i in  range(10000):
    li.append(df['Email'].str.split("@")[i][1])
print(li)
# Out:
# ['yahoo.com', 'reed.com', 'morales-harrison.com', 'olson-robinson.info', 'gmail.com', 'gmail.com', 'yahoo.com', 'parks.info', 'rasmussen.com', 'hunt-huerta.com', 'hotmail.com', 'coleman.com', 'hotmail.com', 'yahoo.com', 'yahoo.com', 'yahoo.com', 'wilson.com', 'hall.com', 'yahoo.com', 'gmail.com', 'smith.info', 'hotmail.com', 'gmail.com', 'gardner-meadows.com', 'yahoo.com', 'mooney.com', 'gmail.com', 'hotmail.com', 'yahoo.com', 'yahoo.com', 'hotmail.com', 'hotmail.com', 'atkinson.com', 'yahoo.com', 'carey-davis.com', 'mcdowell.com', 'walsh.com', 'frederick.info', 'boyd-english.org', 'wells-carlson.info', 'dickerson.com', 'yahoo.com', 'gmail.com', 'martinez-thomas.com', 'yahoo.com', 'chambers.com', 'gmail.com', 'glenn.org', 'allen.com', 'gmail.com', 'obrien.org', 'cook-castillo.com', 'hotmail.com', 'yahoo.com', 'hotmail.com', 'yahoo.com', 'lawrence-warren.biz', 'morris.com', 'howe.com', 'walton.org', 'jones.biz', 'gmail.com', 'simmons-gutierrez.org', 'yahoo.com', 'gardner-anderson.com'
# ...

# %%
a.split("@")
# Out:
# ['Mayur', 'Shrotriya']

# %%
a = "Mayur@Shrotriya"

# %%
df['Email'].str.split("@")[0][1]
# Out:
# 'yahoo.com'

# %%
df1 = df.copy()

# %%
df1["xx","email_provider"] = df["Email"].str.split("@")

# %%
df1
# Out:
#                                                 Address    Lot AM or PM  \
# 0     16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                      Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4     23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# ...                                                 ...    ...      ...
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# ...

# %%
df["Email"].str.split("@")
# Out:
# 0                    [pdunlap, yahoo.com]
# 1                   [anthony41, reed.com]
# 2       [amymiller, morales-harrison.com]
# 3          [brent16, olson-robinson.info]
# 4          [christopherwright, gmail.com]
#                       ...
# 9995            [iscott, wade-garner.com]
# 9996                [mary85, hotmail.com]
# 9997                 [tyler16, gmail.com]
# 9998           [elizabethmoore, reid.net]
# 9999             [rachelford, vaughn.com]
# Name: Email, Length: 10000, dtype: object

# %%
a = "jasbdjb"
str.strip

# %%
a[a.find("d")+1:]
# Out:
# 'jb'

# %%
df["Email"].str.it[df["Email"].str.find("@"):]
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#         ..
# 9995   NaN
# 9996   NaN
# 9997   NaN
# 9998   NaN
# 9999   NaN
# Name: Email, Length: 10000, dtype: float64

# %%
df["Email"].values[df["Email"].str.find("@"):]
# Out:
# array(['pdunlap@yahoo.com', 'anthony41@reed.com',
#        'amymiller@morales-harrison.com', ..., 'tyler16@gmail.com',
#        'elizabethmoore@reid.net', 'rachelford@vaughn.com'], dtype=object)

# %%
df.groupby(by='Email').count()
# Out:
#                             Address  Lot  AM or PM  Browser Info  Company  \
# Email
# aabbott@hotmail.com               1    1         1             1        1
# aacosta@maddox-mann.info          1    1         1             1        1
# aallen@yahoo.com                  1    1         1             1        1
# aalvarez@yahoo.com                1    1         1             1        1
# aandersen@gmail.com               1    1         1             1        1
# ...                             ...  ...       ...           ...      ...
# zwhite@nichols-willis.com         1    1         1             1        1
# zwilson@yahoo.com                 1    1         1             1        1
# zwright@suarez.biz                1    1         1             1        1
# zyork@fischer-harrison.com        1    1         1             1        1
# zyoung@yahoo.com                  1    1         1             1        1
#
# ...

# %%
df1.columns
# Out:
# Index([               'Address',                    'Lot',
#                      'AM or PM',           'Browser Info',
#                       'Company',            'Credit Card',
#                   'CC Exp Date',       'CC Security Code',
#                   'CC Provider',                  'Email',
#                           'Job',             'IP Address',
#                      'Language',         'Purchase Price',
#        ('xx', 'email_provider'), ('xx', 'email provider'),
#                            'xx',         'email provider'],
#       dtype='object')

# %%
df1[('xx', 'email provider')].str.split()
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#         ..
# 9995   NaN
# 9996   NaN
# 9997   NaN
# 9998   NaN
# 9999   NaN
# Name: (xx, email provider), Length: 10000, dtype: float64

# %%
df1
# Out:
#                                                 Address    Lot AM or PM  \
# 0     16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                      Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4     23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# ...                                                 ...    ...      ...
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# ...

# %%
df["Email"].str.splitlines()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\SWAPNI~1\AppData\Local\Temp/ipykernel_14064/3125124204.py in <module>
# ----> 1 df["Email"].str.splitlines()
#
# AttributeError: 'StringMethods' object has no attribute 'splitlines'

# %%
[i for v,i in df["Email"].str.split("@").values]
# Out:
# ['yahoo.com',
#  'reed.com',
#  'morales-harrison.com',
#  'olson-robinson.info',
#  'gmail.com',
#  'gmail.com',
#  'yahoo.com',
#  'parks.info',
#  'rasmussen.com',
#  'hunt-huerta.com',
#  'hotmail.com',
#  'coleman.com',
#  'hotmail.com',
#  'yahoo.com',
#  'yahoo.com',
#  'yahoo.com',
#  'wilson.com',
#  'hall.com',
#  'yahoo.com',
#  'gmail.com',
#  'smith.info',
#  'hotmail.com',
#  'gmail.com',
#  'gardner-meadows.com',
#  'yahoo.com',
#  'mooney.com',
#  'gmail.com',
#  'hotmail.com',
#  'yahoo.com',
#  'yahoo.com',
#  'hotmail.com',
#  'hotmail.com',
#  'atkinson.com',
#  'yahoo.com',
#  'carey-davis.com',
#  'mcdowell.com',
#  'walsh.com',
#  'frederick.info',
#  'boyd-english.org',
#  'wells-carlson.info',
#  'dickerson.com',
#  'yahoo.com',
#  'gmail.com',
#  'martinez-thomas.com',
#  'yahoo.com',
#  'chambers.com',
#  'gmail.com',
#  'glenn.org',
#  'allen.com',
#  'gmail.com',
#  'obrien.org',
#  'cook-castillo.com',
#  'hotmail.com',
#  'yahoo.com',
#  'hotmail.com',
# ...

# %%
df1
# Out:
#                                                 Address    Lot AM or PM  \
# 0     16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                      Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4     23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# ...                                                 ...    ...      ...
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# ...

# %%
df1["e2"] = li

# %%
df1
# Out:
#                                                 Address    Lot AM or PM  \
# 0     16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                      Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4     23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# ...                                                 ...    ...      ...
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# ...
